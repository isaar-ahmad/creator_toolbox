# %% [markdown]
# <a href="https://www.kaggle.com/code/isaarahmad/subtitle-creator?scriptVersionId=148460148" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# User inputs
youtube_video_url = "https://youtu.be/H50Azi7mzIs"
model_size = "large" #options : small, medium, large
task_type = "transcribe" # options : translate/transcribe
subtitle_format = "srt"
#### Do not edit below this line

command = "yt_whisper"

# %%
# Install YT-whisper (pull 38)
# !pip install git+https://github.com/m1guelpf/yt-whisper.git@refs/pull/38/merge

# More packages
# !pip install ffmpeg-python
# !apt update -y -q
# !apt install ffmpeg -y -q
# Out:
# ...
#   Cloning https://github.com/m1guelpf/yt-whisper.git (to revision refs/pull/38/merge) to /tmp/pip-req-build-uvog9ad2
#   Running command git clone --filter=blob:none --quiet https://github.com/m1guelpf/yt-whisper.git /tmp/pip-req-build-uvog9ad2
#   WARNING: Did not find branch or tag 'refs/pull/38/merge', assuming revision or ref.
#   Running command git fetch -q https://github.com/m1guelpf/yt-whisper.git refs/pull/38/merge
#   Running command git checkout -q 3a8eb2087872c0187c46e8159a68ca72324b04f8
#   Resolved https://github.com/m1guelpf/yt-whisper.git to commit 3a8eb2087872c0187c46e8159a68ca72324b04f8
# done
# ...
#   Cloning https://github.com/openai/whisper.git (to revision main) to /tmp/pip-install-777p8du5/openai-whisper_b953b9ab09a549b7a3cba1598035cc27
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-install-777p8du5/openai-whisper_b953b9ab09a549b7a3cba1598035cc27
# ...

# %%
import subprocess
cmd = [command, youtube_video_url, "--task", task_type, "--model", model_size, "--format", subtitle_format ]
subprocess.run(cmd)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 100%|██████████████████████████████████████| 2.87G/2.87G [00:18<00:00, 169MiB/s]
# Downloaded video "Intercontinental Ballistic Missile Gambit (real opening)". Generating subtitles...
# Detected language: English
# 100%|██████████| 15755/15755 [00:32<00:00, 485.80frames/s]
# Saved SRT to /kaggle/working/Intercontinental_Ballistic_Missile_Gambit__real_opening.srt
# CompletedProcess(args=['yt_whisper', 'https://youtu.be/H50Azi7mzIs', '--task', 'transcribe', '--model', 'large', '--format', 'srt'], returncode=0)

# %%
# Define function download_file() : zip the vtt file and generate downloadable link
import os
import subprocess
from IPython.display import FileLink, display

def download_file(path, download_file_name):
    os.chdir('/kaggle/working/')
    zip_name = f"/kaggle/working/{download_file_name}.zip"
    command = f"zip {zip_name} {path} -r"
    result = subprocess.run(command, shell=True, capture_output=True, text=True)
    if result.returncode != 0:
        print("Unable to run zip command!")
        print(result.stderr)
        return
    display(FileLink(f'{download_file_name}.zip'))

# %%
download_path = "/kaggle/working/"

# Find the vtt file that was created during translation/transcription process.
files = os.listdir(download_path)
srt_files = [f for f in files if f.endswith('.srt')]

if srt_files:
    first_srt_file = srt_files[0]
    print(f"File found : {first_srt_file}")
else:
    print("No .srt files found.")

# Generate downloadable link
download_file(srt_files[0], 'out')
# Out:
# File found : Intercontinental_Ballistic_Missile_Gambit__real_opening.srt
# /kaggle/working/out.zip
